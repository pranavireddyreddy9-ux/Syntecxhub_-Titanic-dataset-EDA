# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.groupby('sex')['survived'].mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
df.groupby('class')['survived'].mean()
# Out:
# /tmp/ipython-input-2019280195.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('class')['survived'].mean()
# class
# First     0.629630
# Second    0.472826
# Third     0.242363
# Name: survived, dtype: float64

# %%
df['age_group'] = pd.cut(
    df['age'],
    bins=[0, 12, 18, 40, 60, 90],
    labels=['Child', 'Teen', 'Adult', 'Mid-Age', 'Senior']
)

df.groupby('age_group')['survived'].mean()
# Out:
# /tmp/ipython-input-2326862177.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')['survived'].mean()
# age_group
# Child      0.579710
# Teen       0.428571
# Adult      0.388235
# Mid-Age    0.390625
# Senior     0.227273
# Name: survived, dtype: float64

# %%
sns.barplot(x='sex', y='survived', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x='class', y='survived', data=df)
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.boxplot(x='survived', y='age', data=df)
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.violinplot(x='survived', y='age', data=df)
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
from IPython.display import Markdown

Markdown("""
###  **Insights from Titanic EDA**
- Women had much higher survival rates than men.
- 1st class passengers survived the most, 3rd class the least.
- Children and teens had better survival chances compared to adults.
- Age and deck columns have major missing values.
- Socio-economic status played a major role in survival probability.
""")
# Out:
# ###  **Insights from Titanic EDA**
# - Women had much higher survival rates than men.
# - 1st class passengers survived the most, 3rd class the least.
# - Children and teens had better survival chances compared to adults.
# - Age and deck columns have major missing values.
# - Socio-economic status played a major role in survival probability.
